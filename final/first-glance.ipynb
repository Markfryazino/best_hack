# %%
import numpy as np
import pandas as pd

# %%
kaggle = pd.read_csv('kaggle_data/weatherAUS.csv')
print(kaggle.shape)
kaggle.head()
# Out:
# (142193, 24)
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
train = pd.read_csv('hack_data/training.csv', sep=';')
test = pd.read_csv('hack_data/test.csv', sep=';')

exain = pd.read_csv('hack_data/train_excel.csv')
exest = pd.read_csv('hack_data/test_excel.csv')
# Out:
# /home/data_sapiens/Anaconda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(test.shape)
print(exest.shape)
# Out:
# (17601, 23)
# (17601, 22)

# %%
test.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2015-10-27   Albury     13.6     25.3       0.0          NaN       NaN
# 1  2015-10-28   Albury      6.2     25.5       0.0          NaN       NaN
# 2  2015-10-29   Albury      9.3     27.9       0.0          NaN       NaN
# 3  2015-10-30   Albury      9.7     28.1       0.0          NaN       NaN
# 4  2015-10-31   Albury     17.1     21.7       5.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0          SE           48.0         SE  ...        41.0         30.0
# 1          NE           19.0        ENE  ...        54.0         29.0
# 2          SE           22.0        ESE  ...        55.0         22.0
# 3         ENE           28.0         SE  ...        59.0         36.0
# 4         ENE           28.0         SE  ...        90.0         77.0
#
#    Pressure9am  Pressure3pm  Cloud9am Cloud3pm Temp9am  Temp3pm  RainToday  \
# ...

# %%
kaggle['Date'] = kaggle['Date'].apply(pd.to_datetime)

# %%
kaggle['Date']
# Out:
# 0        2008-12-01
# 1        2008-12-02
# 2        2008-12-03
# 3        2008-12-04
# 4        2008-12-05
#             ...
# 142188   2017-06-20
# 142189   2017-06-21
# 142190   2017-06-22
# 142191   2017-06-23
# 142192   2017-06-24
# Name: Date, Length: 142193, dtype: datetime64[ns]

# %%
test_date = exest['Date'].apply(pd.to_datetime)
test_date.describe()
# Out:
# count                   17601
# unique                    754
# top       2017-01-08 00:00:00
# freq                       30
# first     2014-10-14 00:00:00
# last      2017-06-25 00:00:00
# Name: Date, dtype: object

# %%
test_date = test['Date'].apply(pd.to_datetime)
test_date.describe()
# Out:
# count                   17601
# unique                    754
# top       2017-06-21 00:00:00
# freq                       30
# first     2014-10-14 00:00:00
# last      2017-06-25 00:00:00
# Name: Date, dtype: object

# %%
exest.head()
# Out:
#          Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0  2016-01-03          Moree     18.5     19.7      22.4         30.4
# 1  2015-12-13  NorfolkIsland     20.3     23.1       0.4          4.4
# 2  2015-12-15  NorfolkIsland     18.4     20.4      11.4          6.2
# 3  2015-12-30  NorfolkIsland     18.0     19.6      10.8          5.0
# 4  2016-01-11  NorfolkIsland     20.0     22.0       0.4          5.0
#
#    Sunshine WindGustDir  WindGustSpeed WindDir9am  ... WindSpeed3pm  \
# 0       0.0         ESE           39.0        ENE  ...         17.0
# 1       0.0         NNE           31.0         NE  ...         15.0
# 2       0.0         ESE           41.0        ESE  ...         20.0
# 3       0.0          SE           61.0        ESE  ...         17.0
# 4       0.0          SE           41.0        ESE  ...         22.0
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm Cloud9am Cloud3pm  \
# ...

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
X_train = train[['RISK_MM']]
y_train = train['RainTomorrow'].replace({'Yes': 1, 'No': 0})

# %%
X_test = exest[['RISK_MM']]

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
ta, te, ya, ye = train_test_split(X_train, y_train)

# %%
model.fit(ta, ya)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
ypred = model.predict(te)
accuracy_score(ypred, ye)
# Out:
# 1.0

# %%
ypred.to_csv('RainTomorrow.csv', index=False, )

# %%
train2 = pd.read_csv('hack_data_2/training.csv', sep=';')
test2 = pd.read_csv('hack_data_2/test.csv', sep=';')
# Out:
# /home/data_sapiens/Anaconda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
test2.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2015-10-27   Albury     13.6     25.3       0.0          NaN       NaN
# 1  2015-10-28   Albury      6.2     25.5       0.0          NaN       NaN
# 2  2015-10-29   Albury      9.3     27.9       0.0          NaN       NaN
# 3  2015-10-30   Albury      9.7     28.1       0.0          NaN       NaN
# 4  2015-10-31   Albury     17.1     21.7       5.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... WindSpeed9am  WindSpeed3pm  \
# 0          SE           48.0         SE  ...         26.0          17.0
# 1          NE           19.0        ENE  ...          6.0          11.0
# 2          SE           22.0        ESE  ...          9.0          15.0
# 3         ENE           28.0         SE  ...          9.0          17.0
# 4         ENE           28.0         SE  ...         15.0          19.0
#
#    Humidity9am  Humidity3pm  Pressure9am Pressure3pm Cloud9am  Cloud3pm  \
# ...
